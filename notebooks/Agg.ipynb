# %%
import pandas as pd
import numpy as np

# %%
final_df = pd.read_csv("../data/processed/final_df.csv")

# %%
 DBSCAN_8 = pd.read_csv("../data/results/DBSCANclusters_index_df.csv")

# %%
DBSCAN_8
# Out:
#        id_student age_band gender      highest_education  n_assignments  \
# 0           11391     55<=      M       HE Qualification              5
# 1           28400    35-55      F       HE Qualification              5
# 2           31604    35-55      F  A Level or Equivalent              5
# 3           32885     0-35      F     Lower Than A Level              5
# 4           38053    35-55      M  A Level or Equivalent              5
# ...           ...      ...    ...                    ...            ...
# 26716     2620947     0-35      F  A Level or Equivalent              9
# 26717     2645731    35-55      F     Lower Than A Level              9
# 26718     2648187     0-35      F  A Level or Equivalent              9
# 26719     2679821    35-55      F     Lower Than A Level              2
# 26720     2684003    35-55      F       HE Qualification              7
#
#        mean_score  final_result  total_clicks  studied_credits  \
# ...

# %%
DBSCAN_8.dtypes
# Out:
# id_student             int64
# age_band              object
# gender                object
# highest_education     object
# n_assignments          int64
# mean_score           float64
# final_result           int64
# total_clicks           int64
# studied_credits        int64
# region                object
# code_module           object
# clicks_per_asmt      float64
# cluster_result         int64
# dtype: object

# %%
DBSCAN_8_agg = DBSCAN_8.groupby('cluster_result').agg(mean_score=('mean_score', 'mean'), 
                                                    mean_asmt=('n_assignments', 'mean'), 
                                                    mean_clicks=('total_clicks', 'mean'), 
                                                    mean_result=('final_result', 'mean'), 
                                                    id_count=('final_result', 'count'),
                                                    region_mode=('region', pd.Series.mode))

# %%
DBSCAN_8_agg
# Out:
#                 mean_score  mean_asmt  mean_clicks  mean_result  id_count  \
# cluster_result
# 0                66.813917   5.312910  1166.452441     1.350769      7475
# 1                75.745537   9.505185  2345.295151     3.005326     10703
# 2                64.437723   5.609273   930.550754     2.000000      4443
# 3                88.064610   9.965652  3096.875652     4.000000      2300
# 4                79.153015   8.490108   752.189748     3.000000      1112
# 5                76.849446  20.629213  4101.606742     3.000000        89
# 6                86.777576   8.130064  1190.955224     4.000000       469
# 7                90.466857  21.292308  8133.107692     3.992308       130
#
#                         region_mode
# cluster_result
# 0                          Scotland
# 1                          Scotland
# 2                          Scotland
# 3                          Scotland
# 4               East Anglian Region
# 5                 South West Region
# ...

# %%
final_df_agg = final_df.groupby('region').agg(mean_score=('mean_score', 'mean'), 
                                                    mean_asmt=('n_assignments', 'mean'), 
                                                    mean_clicks=('total_clicks', 'mean'), 
                                                    mean_result=('final_result', 'mean'), 
                                                    id_count=('final_result', 'count'),
                                                    region_mode=('region', pd.Series.mode))

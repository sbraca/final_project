# %%
import pandas as pd
import umap
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import DBSCAN
import hdbscan

# %matplotlib inline

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
final_df = pd.read_csv("../data/processed/final_df.csv")

# %%
final_df.isnull().sum()
# Out:
# id_student            0
# age_band              0
# gender                0
# highest_education     0
# n_assignments         0
# mean_score           19
# final_result          0
# total_clicks          0
# studied_credits       0
# region                0
# code_module           0
# code_presentation     0
# press_mod             0
# dtype: int64

# %%
def drop_col (df, list):
    df.drop(columns=(list), inplace=True)
    return df

# %%
col_drop = ["press_mod", "code_presentation"]

# %%
drop_col(final_df, col_drop)
# Out:
#        id_student age_band gender      highest_education  n_assignments  \
# 0           11391     55<=      M       HE Qualification              5
# 1           28400    35-55      F       HE Qualification              5
# 2           31604    35-55      F  A Level or Equivalent              5
# 3           32885     0-35      F     Lower Than A Level              5
# 4           38053    35-55      M  A Level or Equivalent              5
# ...           ...      ...    ...                    ...            ...
# 26716     2620947     0-35      F  A Level or Equivalent              9
# 26717     2645731    35-55      F     Lower Than A Level              9
# 26718     2648187     0-35      F  A Level or Equivalent              9
# 26719     2679821    35-55      F     Lower Than A Level              2
# 26720     2684003    35-55      F       HE Qualification              7
#
#        mean_score final_result  total_clicks  studied_credits  \
# 0       82.000000         Pass           934              240
# 1       66.400000         Pass          1435               60
# 2       76.000000         Pass          2158               60
# 3       54.400000         Pass          1034               60
# 4       68.000000         Pass          2445               60
# ...           ...          ...           ...              ...
# 26716   88.888889  Distinction           476               30
# 26717   88.111111  Distinction           893               30
# 26718   76.666667         Pass           312               30
# 26719   91.500000    Withdrawn           275               30
# 26720   82.857143  Distinction           616               30
#
#                      region code_module
# 0       East Anglian Region         AAA
# 1                  Scotland         AAA
# 2         South East Region         AAA
# 3      West Midlands Region         AAA
# 4                     Wales         AAA
# ...                     ...         ...
# 26716              Scotland         GGG
# 26717   East Anglian Region         GGG
# 26718          South Region         GGG
# 26719     South East Region         GGG
# 26720      Yorkshire Region         GGG
#
# [26721 rows x 11 columns]

# %%
final_df.set_index(['id_student'], inplace=True)

# %%
final_df[final_df.isnull().any(axis=1)]
# Out:
#            age_band gender      highest_education  n_assignments  mean_score  \
# id_student
# 186780        35-55      F  A Level or Equivalent              0         NaN
# 549713        35-55      F     Lower Than A Level              0         NaN
# 554393        35-55      M  A Level or Equivalent              0         NaN
# 606501         0-35      F  A Level or Equivalent              0         NaN
# 654422         0-35      F        No Formal quals              0         NaN
# 555297         0-35      M     Lower Than A Level              0         NaN
# 557247         0-35      F  A Level or Equivalent              0         NaN
# 557247         0-35      F  A Level or Equivalent              0         NaN
# 427248        35-55      F  A Level or Equivalent              0         NaN
# 676642         0-35      M     Lower Than A Level              0         NaN
# 694548         0-35      M  A Level or Equivalent              0         NaN
# 174436        35-55      F     Lower Than A Level              0         NaN
# 545791        35-55      M     Lower Than A Level              0         NaN
# 546164        35-55      M     Lower Than A Level              0         NaN
# 126074        35-55      M     Lower Than A Level              0         NaN
# 599994         0-35      M  A Level or Equivalent              0         NaN
# 610738        35-55      F     Lower Than A Level              0         NaN
# 480914         0-35      F        No Formal quals              0         NaN
# 648110         0-35      F     Lower Than A Level              0         NaN
#
#            final_result  total_clicks  studied_credits                region  \
# id_student
# 186780        Withdrawn            30              120  North Western Region
# 549713        Withdrawn            75               60  West Midlands Region
# 554393             Fail            21               60  West Midlands Region
# 606501        Withdrawn             9              120  West Midlands Region
# 654422        Withdrawn            31               60  East Midlands Region
# 555297        Withdrawn           155               60  North Western Region
# 557247        Withdrawn           576               60      Yorkshire Region
# 557247        Withdrawn           576               60      Yorkshire Region
# 427248        Withdrawn           317              120  North Western Region
# 676642        Withdrawn            62               60     South West Region
# 694548        Withdrawn           117               90          North Region
# 174436             Fail           101               60                 Wales
# 545791        Withdrawn            20              120  West Midlands Region
# 546164        Withdrawn           381               60          South Region
# 126074        Withdrawn           209              120  West Midlands Region
# 599994        Withdrawn           147               60          North Region
# 610738             Fail           157               30         London Region
# 480914        Withdrawn             8               30   East Anglian Region
# 648110        Withdrawn            87               60         London Region
#
#            code_module
# id_student
# 186780             BBB
# 549713             BBB
# 554393             BBB
# 606501             BBB
# 654422             BBB
# 555297             DDD
# 557247             DDD
# 557247             DDD
# 427248             DDD
# 676642             DDD
# 694548             EEE
# 174436             FFF
# 545791             FFF
# 546164             FFF
# 126074             FFF
# 599994             FFF
# 610738             GGG
# 480914             GGG
# 648110             GGG

# %%
final_df['n_assignments'] = np.where((final_df.n_assignments == 0), 7, final_df.n_assignments)

# %%
final_df['mean_score'] = np.where((final_df.mean_score == 0), 72.83, final_df.mean_score)

# %%
final_df["mean_score"].fillna(72.83, inplace = True)

# %%
final_df['clicks_per_asmt'] = final_df['total_clicks']/final_df['n_assignments']

# %%
final_df.describe()
# Out:
#        n_assignments    mean_score  total_clicks  studied_credits  \
# count   26721.000000  26721.000000  26721.000000     26721.000000
# mean        7.752292     72.925100   1792.429812        77.769357
# std         4.537417     15.348637   2094.342100        39.026739
# min         1.000000      1.000000      1.000000        30.000000
# 25%         4.000000     64.888889    460.000000        60.000000
# 50%         7.000000     75.714286   1082.000000        60.000000
# 75%        11.000000     84.047619   2383.000000        90.000000
# max        28.000000    100.000000  28615.000000       630.000000
#
#        clicks_per_asmt
# count     26721.000000
# mean        241.960057
# std         239.521776
# min           0.272727
# 25%          87.000000
# 50%         175.500000
# 75%         318.000000
# max        4108.000000

# %%
clustering_df = pd.DataFrame(data=final_df, columns=["n_assignments", "total_clicks","studied_credits", "mean_score"])

# %% [markdown]
# # Scaling

# %%
FEATS = ['n_assignments','total_clicks', 'studied_credits', 'mean_score']

# %%
transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='mean')), 
                ('scaler', StandardScaler())])

# %%
preprocessor = \
ColumnTransformer(transformers=[('num', transformer, FEATS)])

# %%
preprocessor
# Out:
# ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('num',
#                                  Pipeline(memory=None,
#                                           steps=[('imputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                                                 fill_value=None,
#                                                                 missing_values=nan,
#                                                                 strategy='mean',
#                                                                 verbose=0)),
#                                                  ('scaler',
#                                                   StandardScaler(copy=True,
#                                                                  with_mean=True,
#                                                                  with_std=True))],
#                                           verbose=False),
#                                  ['n_assignments', 'total_clicks',
#                                   'studied_credits', 'mean_score'])],
#                   verbose=False)

# %%
clustering_1 = pd.DataFrame(data=preprocessor.fit_transform(final_df))

# %%
clustering_1
# Out:
#               0         1         2         3
# 0     -0.606588 -0.409888  4.156988  0.591262
# 1     -0.606588 -0.170668 -0.455321 -0.425134
# 2     -0.606588  0.174555 -0.455321  0.200341
# 3     -0.606588 -0.362140 -0.455321 -1.206977
# 4     -0.606588  0.311593 -0.455321 -0.320888
# ...         ...       ...       ...       ...
# 26716  0.274987 -0.628577 -1.224039  1.040098
# 26717  0.274987 -0.429465 -1.224039  0.989423
# 26718  0.274987 -0.706884 -1.224039  0.243776
# 26719 -1.267770 -0.724551 -1.224039  1.210221
# 26720 -0.165801 -0.561729 -1.224039  0.647108
#
# [26721 rows x 4 columns]

# %% [markdown]
# # UMAP

# %%
clustering_1 = clustering_1.to_numpy()

# %%
reducer_1 = umap.UMAP(random_state=42, metric='cosine', output_metric='euclidean')
reducer_1.fit(clustering_1.data)
# Out:
# UMAP(a=None, angular_rp_forest=True, b=None,
#      force_approximation_algorithm=False, init='spectral', learning_rate=1.0,
#      local_connectivity=1.0, low_memory=False, metric='cosine',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=15, negative_sample_rate=5, output_metric='euclidean',
#      output_metric_kwds=None, random_state=42, repulsion_strength=1.0,
#      set_op_mix_ratio=1.0, spread=1.0, target_metric='categorical',
#      target_metric_kwds=None, target_n_neighbors=-1, target_weight=0.5,
#      transform_queue_size=4.0, transform_seed=42, unique=False, verbose=False)

# %%
embedding_1 = reducer_1.transform(clustering_1.data)

# %%
plt.scatter(embedding_1[:, 0], embedding_1[:, 1], cmap='Spectral', s=5)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(11)-1).set_ticks(np.arange(11))
plt.title('UMAP 1 OU Dataset', fontsize=24);

# %%
clustering_1 = hdbscan.HDBSCAN(min_cluster_size=600, min_samples=4)

clustering_1.fit(embedding_1)

clustering_1
# Out:
# HDBSCAN(algorithm='best', allow_single_cluster=False, alpha=1.0,
#         approx_min_span_tree=True, cluster_selection_epsilon=0.0,
#         cluster_selection_method='eom', core_dist_n_jobs=4,
#         gen_min_span_tree=False, leaf_size=40,
#         match_reference_implementation=False, memory=Memory(location=None),
#         metric='euclidean', min_cluster_size=600, min_samples=4, p=None,
#         prediction_data=False)

# %%
plt.scatter(embedding_1[:, 0], embedding_1[:, 1], c=clustering_1.labels_, cmap='Spectral', s=4)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(len(np.unique(clustering_1.labels_)))-0.5).set_ticks(np.arange(len(np.unique(clustering_1.labels_))))
plt.title('HDBSCAN 1 OU Dataset', fontsize=24);

# %%
final_df['cluster']=clustering_1.labels_

# %%
final_df.to_csv("../data/processed/five_clusters.csv")

# %%
from sklearn.metrics  import silhouette_score

# %%
import sklearn

# %%
sklearn.metrics.silhouette_score(embedding_1, clustering_1.labels_, metric='euclidean', sample_size=None, random_state=None)
# Out:
# 0.40851462
